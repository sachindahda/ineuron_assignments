# %%
for i in range(0,5):
    for j in range(0,i):
        print('*',end="")
    print('\n')
for k in range(5,0,-1):
    for l in range(k,0,-1):
        print('*',end="")
    print('\n')
# Out:
# *
#
# **
#
# ***
#
# ****
#
# *****
#
# ****
#
# ***
#
# **
#
# *

# %%
name=input()
print(name[::-1])
# Out:
# sachin
# nihcas
